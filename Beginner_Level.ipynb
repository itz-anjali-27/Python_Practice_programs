# %% [markdown]
# # Beginner Level

# %% [markdown]
# ### 1. Print "Hello World"

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### 2. Take input and print its square

# %%
n=int(input("enter number : "))
print("square : ",n*n)
# Out:
# enter number :  2
# square :  4

# %% [markdown]
# ### 3.Check even or odd

# %%
n=int(input("enter number : "))
if(n%2==0):
    print("Even number")
else:
    print("Odd number")
# Out:
# enter number :  3
# Odd number

# %% [markdown]
# ### 4.Find largest of 2 numbers

# %%
n1=int(input("enter number1 : "))
n2=int(input("enter number2 : "))
if(n1>n2):
    print("n1 is largest number")
else:
    print("n2 is largest number")
# Out:
# enter number1 :  2
# enter number2 :  3
# n2 is largest number

# %% [markdown]
# ### 5.Find largest of 3 numbers

# %%
n1=int(input("enter number1 : "))
n2=int(input("enter number2 : "))
n3=int(input("enter number3 : "))
if(n1>n2 and n1>n3):
    print("n1 is largest number")
elif(n2>n1 and n2>n3):
    print("n2 is largest number")
else:
    print("n3 is largest number")
# Out:
# enter number1 :  2
# enter number2 :  3
# enter number3 :  4
# n3 is largest number

# %% [markdown]
# ### 6. Swap two numbers

# %%
n1=int(input("enter number1 : "))
n2=int(input("enter number2 : "))
t=n1
n1=n2
n2=t
print("number1 :  ",n1)
print("number2 :  ",n2)
# Out:
# enter number1 :  2
# enter number2 :  3
# number1 :   3
# number2 :   2

# %% [markdown]
# ### 7. Check positive ,negative or zero

# %%
n=int(input("enter number : "))
if(n>0):
    print("Positive number")
elif(n<0): 
      print("Negative number")
else:
      print("Zero")
# Out:
# enter number :  3
# Positive number

# %% [markdown]
# ### 8. Simple calculator(using if-else)

# %%
n1=int(input("enter number1 : "))
n2=int(input("enter number2 : "))
op=input("enter operator : ")
if(op=='+'):
    print("addition : ",n1+n2)
elif(op=='-'):
    print("subtraction : ",n1-n2)  
elif(op=='*'):
    print("multiplicatin : ",n1*n2)
elif(op=='/'):
    print("addision : ",n1/n2)   
else:
    print("invailid")
# Out:
# enter number1 :  3
# enter number2 :  2
# enter operator :  /
# addision :  1.5

# %% [markdown]
# ### 9.Calculate area of rectangle

# %%
l=int(input("enter value of length : "))
b=int(input("enter value of breadth: "))
area=l*b
print("area : ",area)
# Out:
# enter value of length :  2
# enter value of breadth:  3
# area :  6

# %% [markdown]
# ### 10. Convert Fahrenheit to Celsius formula

# %%
f=int(input("enter value of fahrenheit : "))
c=(f-32)*5/9
print("celsius : ",c)
# Out:
# enter value of fahrenheit :  98
# celsius :  36.666666666666664
